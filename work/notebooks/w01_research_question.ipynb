# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadusmanray-ops/flyrank-internship-ml/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/muhammadusmanray-ops/flyrank-internship-ml/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# My Lane: Refresh / Content Opportunity Scoring
#
# Why: I chose this lane because prioritizing content refreshes is a highly practical and high-impact SEO decision. Instead of manually auditing thousands of pages, using machine learning helps us rank pages by their opportunity for recovery. The starter notebook showed a clear 3x lift over simple rules, proving that data-driven scoring works.

# %%
import os
import sys
import subprocess
import pandas as pd

# 1. Colab mein repository clone karein agar pehle se nahi hai
REPO_DIR = "flyrank-internship-ml"
REPO_URL = "https://github.com/muhammadusmanray-ops/flyrank-internship-ml.git"

if "google.colab" in sys.modules:
    if not os.path.exists(REPO_DIR):
        print("Cloning repository...")
        subprocess.run(["git", "clone", REPO_URL, REPO_DIR], check=True)

    # Directory change karein repo ke andar
    if os.path.exists(REPO_DIR) and not os.getcwd().endswith(REPO_DIR):
        os.chdir(REPO_DIR)

# 2. File find aur read karein
path = "data/raw/content_refresh_anonymized.csv"
if not os.path.exists(path):
    for root, dirs, files in os.walk("."):
        if "content_refresh_anonymized.csv" in files:
            path = os.path.join(root, "content_refresh_anonymized.csv")
            break

df = pd.read_csv(path)
print(f"\n1. Total Rows (Pages): {len(df)}")
print(f"2. Average Position: {df['avg_position'].mean():.2f}")
print(f"3. Average CTR (Click-Through Rate): {df['ctr'].mean():.4f}")
# Out:
# Cloning repository...
#
# 1. Total Rows (Pages): 30000
# 2. Average Position: 16.34
# 3. Average CTR (Click-Through Rate): 0.5107

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# The Decision: Which outdated or declining pages should the content team rewrite or update first?
#
# The Action: The content team will rewrite, re-optimize, or update the targeted pages.
#
# The Cost of a Wrong Call:
#
# False Positive (wrongly flag to update): We waste content writers' time and money editing a page that didn't need it.
# False Negative (miss a declining page): We lose organic search traffic and revenue to competitors.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# What I CAN claim: We can observe historical correlation between page metrics (like age, impressions) and performance drops, and rank pages to support content team decisions.
#
# What I CANNOT claim: We cannot claim that we have "predicted Google's algorithm" or that updating these pages will guaranteed rank #1 on Google. We are helping humans prioritize their queue, not hacking search engines.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Completed all framing questions and verified dataset numbers.
